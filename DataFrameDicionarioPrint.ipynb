# %%
import pandas as pd
#Crie dados em um dicionario de produtos com as colulas: produdo, preço, quantidade de estoque, disponivel(True ou false)
dados_produtos= {
    'Produto': ['Celular', 'NoteBook', 'Mouse', 'Teclado'],
    'Preco(R$)': [1500, 4200, 80, 150],
    'Quantidade em Estoque': [50, 20, 150, 100],
    'Disponivel': [True, True, True, False]

}

#Crie o dataFrame a partir do dicionario
df_produtos = pd.DataFrame(dados_produtos)

#Exiba o dataFrame
print(df_produtos)
# Out:
#     Produto  Preco(R$)  Quantidade em Estoque  Disponivel
# 0   Celular       1500                     50        True
# 1  NoteBook       4200                     20        True
# 2     Mouse         80                    150        True
# 3   Teclado        150                    100       False
